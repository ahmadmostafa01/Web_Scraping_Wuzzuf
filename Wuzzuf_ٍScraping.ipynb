# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import math
def find_no_of_jobs(job):
    req  = requests.get('https://wuzzuf.net/search/jobs/?a=hpb&q=' + job.replace(' ', '%20'))
    soup = BeautifulSoup(req.content, 'lxml')
    jobs = int(soup.find({'strong'}).text.replace(',', ''))
    pages = math.ceil(jobs / 15)
    return jobs, pages

# %%
print(find_no_of_jobs('Machine learning'))
print(find_no_of_jobs('Data science'))
print(find_no_of_jobs('Data analysis'))
print(find_no_of_jobs('Business intelligence'))
# Out:
# (35, 3)
# (557, 38)
# (614, 41)
# (73, 5)

# %%
def scrap_pages(query):
    num_jobs, num_pages = find_no_of_jobs(query)
    query = query.replace(' ', '%20')
    titles_lst, links_lst, occupations_lst, companies_lst, specs_lst = [], [], [], [], []
    for pageNo in range(num_pages):
        page = requests.get('https://wuzzuf.net/search/jobs/?a=hpb&q=' + query + '&start=' + str(pageNo))
        soup = BeautifulSoup(page.content, 'lxml')

        titles = soup.find_all("h2", {'class': 'css-m604qf'})
        titles_lst += [title.a.text for title in titles]
        links_lst += ['https://wuzzuf.net' + title.a['href'] for title in titles]

        occupations = soup.find_all("div", {'class': 'css-1lh32fc'})
        occupations_lst += [occupation.text for occupation in occupations]

        companies = soup.find_all("a", {'class': 'css-17s97q8'})
        companies_lst += [company.text for company in companies]

        specs = soup.find_all("div", {'class': 'css-y4udm8'})
        specs_lst += [spec.text for spec in specs]

    scraped_data = {}
    scraped_data['Title'] = titles_lst
    scraped_data['Link'] = links_lst
    scraped_data['Occupation'] = occupations_lst
    scraped_data['Company'] = companies_lst
    scraped_data['Specs'] = specs_lst

    df = pd.DataFrame(scraped_data)
    
    return scraped_data, df

# %%
ml_dict, ml_df = scrap_pages('Machine learning')

# %%
ml_df
# Out:
#                                             Title  \
# 0                Senior Machine Learning Engineer
# 1                       Machine Learning Engineer
# 2                                  Data Scientist
# 3                              Software Team Lead
# 4                   Python Developer - Internship
# 5                       Senior Research Scientist
# 6                      Junior Production Engineer
# 7                           Training Section Head
# 8                           Senior Java Developer
# 9               Junior Embedded Software Engineer
# 10                 Data Analyst, Egypt Impact Lab
# 11                         Outdoor Sales Engineer
# 12                          Senior Odoo Developer
# 13                                        BI Lead
# 14             IT Technical Support - (Help Desk)
# 15                       Administrator (Helpdesk)
# 16                            HR Business Partner
# 17                   Application Support Engineer
# 18                           Distribution manager
# 19        QA Validation and Qualification Officer
# 20               Electronics Maintenance Engineer
# 21                        Junior Python Developer
# 22                        Business System Analyst
# 23          Odoo Developer & Pre-Sales Specialist
# 24                        Snowflakes DW developer
# 25                             Software Architect
# 26                          NGenius POS Developer
# 27                                  Sales Manager
# 28                          Data Entry Specialist
# 29                              Backend Developer
# 30                            Front End Developer
# 31  Mechanical Engineer - Pharmaceutical Industry
# 32                       Computer Vision Engineer
# 33   Full Stack Developer (.Net Core & Angular 9)
# 34                                  Data Engineer
#
#                                                  Link  \
# 0   https://wuzzuf.net/jobs/p/YDxhBIJimaOR-Senior-...
# 1   https://wuzzuf.net/jobs/p/63GDVXe1mip9-Machine...
# 2   https://wuzzuf.net/jobs/p/MXunj0kftZ1D-Data-Sc...
# 3   https://wuzzuf.net/jobs/p/tDpJrj9GeBO6-Softwar...
# 4   https://wuzzuf.net/internship/ks2Azi1kboPo-Pyt...
# 5   https://wuzzuf.net/jobs/p/WjuL0LeHiwuo-Senior-...
# 6   https://wuzzuf.net/jobs/p/45lysRZRecXG-Junior-...
# 7   https://wuzzuf.net/jobs/p/KY4bSeU9W8aU-Trainin...
# 8   https://wuzzuf.net/jobs/p/1TQAeepNOzTT-Senior-...
# 9   https://wuzzuf.net/jobs/p/etWvboHXv2KK-Junior-...
# 10  https://wuzzuf.net/jobs/p/pupdhlXqPr2x-Data-An...
# 11  https://wuzzuf.net/jobs/p/iDRrxWxaWVh7-Outdoor...
# 12  https://wuzzuf.net/jobs/p/agIv6WyiyzOh-Senior-...
# 13  https://wuzzuf.net/jobs/p/tpQxzx6h6Bck-BI-Lead...
# 14  https://wuzzuf.net/jobs/p/bJ0PHeQCefXj-IT-Tech...
# 15  https://wuzzuf.net/jobs/p/YmXXOb6m6KSK-Adminis...
# 16  https://wuzzuf.net/jobs/p/KWSpfwYullLN-HR-Busi...
# 17  https://wuzzuf.net/jobs/p/W7hQTnpL8wuO-Applica...
# 18  https://wuzzuf.net/jobs/p/7yVywpJez0eW-Distrib...
# 19  https://wuzzuf.net/jobs/p/KV2r7vWQrPHM-QA-Vali...
# 20  https://wuzzuf.net/jobs/p/Yncr9w7VinnH-Electro...
# 21  https://wuzzuf.net/jobs/p/0yvTijkcosNQ-Junior-...
# 22  https://wuzzuf.net/jobs/p/QXK4900FX49X-Busines...
# 23  https://wuzzuf.net/jobs/p/m0lKvrs7EIs1-Odoo-De...
# 24  https://wuzzuf.net/jobs/p/NCFm6413BhR7-Snowfla...
# 25  https://wuzzuf.net/jobs/p/0kUJIMSomjmV-Softwar...
# 26  https://wuzzuf.net/jobs/p/9SRldxbI7qft-NGenius...
# 27  https://wuzzuf.net/jobs/p/nYGSHAY3kiIA-Sales-M...
# 28  https://wuzzuf.net/jobs/p/hxwySiYEX7QV-Data-En...
# 29  https://wuzzuf.net/jobs/p/ZKi6JqDbkE2Y-Backend...
# 30  https://wuzzuf.net/jobs/p/HBU9AY1aefW3-Front-E...
# 31  https://wuzzuf.net/jobs/p/csfKrQZUwUg0-Mechani...
# 32  https://wuzzuf.net/jobs/p/RaI3XrJXdV83-Compute...
# 33  https://wuzzuf.net/jobs/p/SA8PUX5eQl9I-Full-St...
# 34  https://wuzzuf.net/jobs/p/YgnlNerNUQml-Data-En...
#
#                  Occupation  \
# 0   Full TimeWork From Home
# 1                 Full Time
# 2                 Full Time
# 3                 Full Time
# 4                Internship
# 5                 Full Time
# 6                 Full Time
# 7                 Full Time
# 8   Full TimeWork From Home
# 9                 Full Time
# 10                Full Time
# 11                Full Time
# 12                Full Time
# 13                Full Time
# 14                Full Time
# 15                Full Time
# 16       Full TimePart Time
# 17                Full Time
# 18                Full Time
# 19                Full Time
# 20                Full Time
# 21                Full Time
# 22                Full Time
# 23                Full Time
# 24                Full Time
# 25                Full Time
# 26                Full Time
# 27                Full Time
# 28                Full Time
# 29                Full Time
# 30                Full Time
# 31                Full Time
# 32                Full Time
# 33                Full Time
# 34                Full Time
#
#                                               Company  \
# 0                                         Media Sci -
# 1                                          Edentech -
# 2                                          BlinkApp -
# 3                                          TMentors -
# 4                                          TMentors -
# 5                                           Atomica -
# 6                         Delta Egypt For Lighting  -
# 7                             Giza Cable Industries -
# 8                                         Media Sci -
# 9                                         Swift Act -
# 10  National Institute for Governance and Developm...
# 11                                            ACFET -
# 12                                      Blue Ribbon -
# 13                                  Excel Systems   -
# 14                         Raya Customer Experience -
# 15                                           Raya   -
# 16                                         EasyKash -
# 17                                     Caelum Egypt -
# 18                                              MEC -
# 19                                      APEX Pharma -
# 20                                     Confidential -
# 21                                              RDI -
# 22                                              GS1 -
# 23                                         Elitbuzz -
# 24                                       FlairsTech -
# 25                             Perfect Presentation -
# 26                     Network International -Egypt -
# 27                                        Misr salt -
# 28                                            Botit -
# 29                                  Nile University -
# 30                                  Nile University -
# 31                      Global Napi Pharmaceuticals -
# 32                                         Edentech -
# 33                           JRM for Communications -
# 34                                       Centro CDX -
#
#                                                 Specs
# 0   Full TimeWork From HomeExperienced · 5+ Yrs of...
# 1   Full TimeExperienced · 3 - 7 Yrs of Exp · IT/S...
# 2   Full TimeExperienced · 3+ Yrs of Exp · IT/Soft...
# 3   Full TimeManager · 8 - 12 Yrs of Exp · IT/Soft...
# 4   InternshipStudent · IT/Software Development · ...
# 5   Full TimeExperienced · 4+ Yrs of Exp · IT/Soft...
# 6   Full TimeEntry Level · 0 - 1 Yrs of Exp · male...
# 7   Full TimeManager · 10 - 20 Yrs of Exp · Traini...
# 8   Full TimeWork From HomeExperienced · 5+ Yrs of...
# 9   Full TimeEntry Level · 0 - 1 Yrs of Exp · IT/S...
# 10  Full TimeExperienced · 2 - 5 Yrs of Exp · Anal...
# 11  Full TimeExperienced · 2 - 4 Yrs of Exp · Sale...
# 12  Full TimeExperienced · 5+ Yrs of Exp · IT/Soft...
# 13  Full TimeManager · 7+ Yrs of Exp · IT/Software...
# 14  Full TimeEntry Level · 0 - 1 Yrs of Exp · Inst...
# 15  Full TimeEntry Level · 1 - 2 Yrs of Exp · IT/S...
# 16  Full TimePart TimeExperienced · 2 - 5 Yrs of E...
# 17  Full TimeExperienced · 2 - 4 Yrs of Exp · IT/S...
# 18  Full TimeManager · 10+ Yrs of Exp · males_only...
# 19  Full TimeExperienced · 3 - 5 Yrs of Exp · Qual...
# 20  Full TimeExperienced · 2 - 3 Yrs of Exp · Inst...
# 21  Full TimeEntry Level · 1+ Yrs of Exp · IT/Soft...
# 22  Full TimeExperienced · 2 - 5 Yrs of Exp · IT/S...
# 23  Full TimeExperienced · 5+ Yrs of Exp · IT/Soft...
# 24  Full TimeExperienced · 3 - 5 Yrs of Exp · IT/S...
# 25  Full TimeExperienced · 10+ Yrs of Exp · IT/Sof...
# 26  Full TimeExperienced · 6 - 12 Yrs of Exp · IT/...
# 27  Full TimeManager · 8+ Yrs of Exp · Operations/...
# 28  Full TimeEntry Level · 0 - 3 Yrs of Exp · Admi...
# 29  Full TimeEntry Level · 0 - 3 Yrs of Exp · IT/S...
# 30  Full TimeEntry Level · 0 - 3 Yrs of Exp · IT/S...
# 31  Full TimeExperienced · 7 - 10 Yrs of Exp · Eng...
# 32  Full TimeExperienced · 4 - 9 Yrs of Exp · IT/S...
# 33  Full TimeExperienced · 2+ Yrs of Exp · IT/Soft...
# 34  Full TimeExperienced · 3+ Yrs of Exp · IT/Soft...

# %%
da_dict, da_df = scrap_pages('Data analysis')

# %%
ds_dict, ds_df = scrap_pages('Data science')

# %%
bi_dict, bi_df = scrap_pages('Business intelligence')

# %%
def combine_dfs(dfs):
    df = pd.concat(dfs)
    df = df.drop_duplicates()
    return df

# %%
combine_dfs([ml_df, da_df, ds_df, bi_df])
# Out:
#                                             Title  \
# 0                Senior Machine Learning Engineer
# 1                       Machine Learning Engineer
# 2                                  Data Scientist
# 3                              Software Team Lead
# 4                   Python Developer - Internship
# ..                                            ...
# 68  Market Access Lead - GCC (Based in Hurghada )
# 69                               Graphic Designer
# 70                     Financial Analysis Manager
# 71                           Social Media Manager
# 72             Medical Director ( Beauty Clinic )
#
#                                                  Link  \
# 0   https://wuzzuf.net/jobs/p/YDxhBIJimaOR-Senior-...
# 1   https://wuzzuf.net/jobs/p/63GDVXe1mip9-Machine...
# 2   https://wuzzuf.net/jobs/p/MXunj0kftZ1D-Data-Sc...
# 3   https://wuzzuf.net/jobs/p/tDpJrj9GeBO6-Softwar...
# 4   https://wuzzuf.net/internship/ks2Azi1kboPo-Pyt...
# ..                                                ...
# 68  https://wuzzuf.net/jobs/p/vpiUFGkbg2IF-Market-...
# 69  https://wuzzuf.net/jobs/p/gFySRDAhxW7h-Graphic...
# 70  https://wuzzuf.net/jobs/p/K0yvFAdubfkt-Financi...
# 71  https://wuzzuf.net/jobs/p/F5VKBZCZpqP9-Social-...
# 72  https://wuzzuf.net/jobs/p/LJLI03qVmW2E-Medical...
#
#                  Occupation           Company  \
# 0   Full TimeWork From Home       Media Sci -
# 1                 Full Time        Edentech -
# 2                 Full Time        BlinkApp -
# 3                 Full Time        TMentors -
# 4                Internship        TMentors -
# ..                      ...               ...
# 68                Full Time   Caduceus Lane -
# 69                Full Time  GEMS Education -
# 70                Full Time    Confidential -
# 71                Full Time       Venu Apps -
# 72                Full Time             MWG -
#
#                                                 Specs
# 0   Full TimeWork From HomeExperienced · 5+ Yrs of...
# 1   Full TimeExperienced · 3 - 7 Yrs of Exp · IT/S...
# 2   Full TimeExperienced · 3+ Yrs of Exp · IT/Soft...
# 3   Full TimeManager · 8 - 12 Yrs of Exp · IT/Soft...
# 4   InternshipStudent · IT/Software Development · ...
# ..                                                ...
# 68  Full TimeManager · 10 - 15 Yrs of Exp · Busine...
# 69  Full TimeExperienced · 2+ Yrs of Exp · Creativ...
# 70  Full TimeManager · 15 - 20 Yrs of Exp · Accoun...
# 71  Full TimeExperienced · 3 - 5 Yrs of Exp · Writ...
# 72  Full TimeExperienced · 5 - 7 Yrs of Exp · Medi...
#
# [1279 rows x 5 columns]

# %%
def combine_dicts(dicts):
    combined_dict = {}
    for key in dicts[0].keys():
        combined_dict[key] = []
        for dict in dicts:
            combined_dict[key] += dict[key]
    return combined_dict

# %%
all_dicts = combine_dicts([ml_dict, da_dict, ds_dict, bi_dict])

# %%
all_df = pd.DataFrame(all_dicts)
all_df
# Out:
#                                               Title  \
# 0                  Senior Machine Learning Engineer
# 1                         Machine Learning Engineer
# 2                                    Data Scientist
# 3                                Software Team Lead
# 4                     Python Developer - Internship
# ...                                             ...
# 1274  Market Access Lead - GCC (Based in Hurghada )
# 1275                               Graphic Designer
# 1276                     Financial Analysis Manager
# 1277                           Social Media Manager
# 1278             Medical Director ( Beauty Clinic )
#
#                                                    Link  \
# 0     https://wuzzuf.net/jobs/p/YDxhBIJimaOR-Senior-...
# 1     https://wuzzuf.net/jobs/p/63GDVXe1mip9-Machine...
# 2     https://wuzzuf.net/jobs/p/MXunj0kftZ1D-Data-Sc...
# 3     https://wuzzuf.net/jobs/p/tDpJrj9GeBO6-Softwar...
# 4     https://wuzzuf.net/internship/ks2Azi1kboPo-Pyt...
# ...                                                 ...
# 1274  https://wuzzuf.net/jobs/p/vpiUFGkbg2IF-Market-...
# 1275  https://wuzzuf.net/jobs/p/gFySRDAhxW7h-Graphic...
# 1276  https://wuzzuf.net/jobs/p/K0yvFAdubfkt-Financi...
# 1277  https://wuzzuf.net/jobs/p/F5VKBZCZpqP9-Social-...
# 1278  https://wuzzuf.net/jobs/p/LJLI03qVmW2E-Medical...
#
#                    Occupation           Company  \
# 0     Full TimeWork From Home       Media Sci -
# 1                   Full Time        Edentech -
# 2                   Full Time        BlinkApp -
# 3                   Full Time        TMentors -
# 4                  Internship        TMentors -
# ...                       ...               ...
# 1274                Full Time   Caduceus Lane -
# 1275                Full Time  GEMS Education -
# 1276                Full Time    Confidential -
# 1277                Full Time       Venu Apps -
# 1278                Full Time             MWG -
#
#                                                   Specs
# 0     Full TimeWork From HomeExperienced · 5+ Yrs of...
# 1     Full TimeExperienced · 3 - 7 Yrs of Exp · IT/S...
# 2     Full TimeExperienced · 3+ Yrs of Exp · IT/Soft...
# 3     Full TimeManager · 8 - 12 Yrs of Exp · IT/Soft...
# 4     InternshipStudent · IT/Software Development · ...
# ...                                                 ...
# 1274  Full TimeManager · 10 - 15 Yrs of Exp · Busine...
# 1275  Full TimeExperienced · 2+ Yrs of Exp · Creativ...
# 1276  Full TimeManager · 15 - 20 Yrs of Exp · Accoun...
# 1277  Full TimeExperienced · 3 - 5 Yrs of Exp · Writ...
# 1278  Full TimeExperienced · 5 - 7 Yrs of Exp · Medi...
#
# [1279 rows x 5 columns]

# %%
all_df.to_csv('Wuzzuf.csv', index=False)
